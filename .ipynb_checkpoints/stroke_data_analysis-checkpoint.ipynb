# %%
# Import Libraries
import numpy as np
import pandas as pd

# %%
# Import CSV into dataframe
df = pd.read_csv('healthcare-dataset-stroke-data.csv',delimiter=',',header='infer')

# Display the first records in the dataframe
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Print column names
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# Look at the summary stats for each column
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
# Look at the shape of the dataframes
df.shape
# Out:
# (5110, 12)

# %%
# Identify any columns with missing data
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Replace missing values
df["bmi"].fillna("missing", inplace = True)
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
# Identify if there are any duplicated rows
df.duplicated().any()
# Out:
# False

# %%
# Print duplicated rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
# For each column print the unique values
for col in df.columns:
    print(col)
    print(df[col].unique())
    print('\n')
# Out:
# id
# [ 9046 51676 31112 ... 19723 37544 44679]
#
#
# gender
# ['Male' 'Female' 'Other']
#
#
# age
# [6.70e+01 6.10e+01 8.00e+01 4.90e+01 7.90e+01 8.10e+01 7.40e+01 6.90e+01
#  5.90e+01 7.80e+01 5.40e+01 5.00e+01 6.40e+01 7.50e+01 6.00e+01 5.70e+01
#  7.10e+01 5.20e+01 8.20e+01 6.50e+01 5.80e+01 4.20e+01 4.80e+01 7.20e+01
#  6.30e+01 7.60e+01 3.90e+01 7.70e+01 7.30e+01 5.60e+01 4.50e+01 7.00e+01
#  6.60e+01 5.10e+01 4.30e+01 6.80e+01 4.70e+01 5.30e+01 3.80e+01 5.50e+01
#  1.32e+00 4.60e+01 3.20e+01 1.40e+01 3.00e+00 8.00e+00 3.70e+01 4.00e+01
#  3.50e+01 2.00e+01 4.40e+01 2.50e+01 2.70e+01 2.30e+01 1.70e+01 1.30e+01
#  4.00e+00 1.60e+01 2.20e+01 3.00e+01 2.90e+01 1.10e+01 2.10e+01 1.80e+01
#  3.30e+01 2.40e+01 3.40e+01 3.60e+01 6.40e-01 4.10e+01 8.80e-01 5.00e+00
#  2.60e+01 3.10e+01 7.00e+00 1.20e+01 6.20e+01 2.00e+00 9.00e+00 1.50e+01
#  2.80e+01 1.00e+01 1.80e+00 3.20e-01 1.08e+00 1.90e+01 6.00e+00 1.16e+00
#  1.00e+00 1.40e+00 1.72e+00 2.40e-01 1.64e+00 1.56e+00 7.20e-01 1.88e+00
#  1.24e+00 8.00e-01 4.00e-01 8.00e-02 1.48e+00 5.60e-01 4.80e-01 1.60e-01]
#
#
# hypertension
# [0 1]
#
#
# heart_disease
# [1 0]
#
#
# ever_married
# ['Yes' 'No']
#
#
# work_type
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
#
#
# Residence_type
# ['Urban' 'Rural']
#
#
# avg_glucose_level
# [228.69 202.21 105.92 ...  82.99 166.29  85.28]
#
#
# bmi
# [36.6 'missing' 32.5 34.4 24.0 29.0 27.4 22.8 24.2 29.7 36.8 27.3 28.2
#  30.9 37.5 25.8 37.8 22.4 48.9 26.6 27.2 23.5 28.3 44.2 25.4 22.2 30.5
#  26.5 33.7 23.1 32.0 29.9 23.9 28.5 26.4 20.2 33.6 38.6 39.2 27.7 31.4
#  36.5 33.2 32.8 40.4 25.3 30.2 47.5 20.3 30.0 28.9 28.1 31.1 21.7 27.0
#  24.1 45.9 44.1 22.9 29.1 32.3 41.1 25.6 29.8 26.3 26.2 29.4 24.4 28.0
#  28.8 34.6 19.4 30.3 41.5 22.6 56.6 27.1 31.3 31.0 31.7 35.8 28.4 20.1
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']
#
#
# stroke
# [1 0]

# %%
# Change all the age vaues to categorical
df['age'] = pd.qcut(df['age'].rank(method='first'), q=5, labels=['very low', 'low', 'medium', 'high', 'very high'])

# %%
# Change all the average glucose level values to categorical
df['avg_glucose_level'] = pd.qcut(df['avg_glucose_level'].rank(method='first'), q=5, labels=['very low', 'low', 'medium', 'high', 'very high'])

# %%
# Change all the bmi columns to categorical
non_missing_rows = df[df["bmi"] != "missing"]
non_missing_rows['bmi'] = non_missing_rows['bmi'].astype(float)
non_missing_rows['bmi'] = pd.qcut(non_missing_rows['bmi'].rank(method='first'), q=5, labels=['very low', 'low', 'medium', 'high', 'very high'])
missing_rows = df[df["bmi"] == "missing"]
non_missing_rows = non_missing_rows.append(missing_rows, ignore_index=True) 
df = non_missing_rows
df.head()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       id  gender        age  hypertension  heart_disease ever_married  \
# 0   9046    Male  very high             0              1          Yes
# 1  31112    Male  very high             0              1          Yes
# 2  60182  Female     medium             0              0          Yes
# 3   1665  Female  very high             1              0          Yes
# 4  56669    Male  very high             0              0          Yes
#
#        work_type Residence_type avg_glucose_level        bmi   smoking_status  \
# 0        Private          Urban         very high  very high  formerly smoked
# 1        Private          Rural              high       high     never smoked
# 2        Private          Urban         very high       high           smokes
# 3  Self-employed          Rural         very high        low     never smoked
# 4        Private          Urban         very high     medium  formerly smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Describe transformed data
df.describe(include='all')
# Out:
#                   id  gender        age  hypertension  heart_disease  \
# count    5110.000000    5110       5110   5110.000000    5110.000000
# unique           NaN       3          5           NaN            NaN
# top              NaN  Female  very high           NaN            NaN
# freq             NaN    2994       1022           NaN            NaN
# mean    36517.829354     NaN        NaN      0.097456       0.054012
# std     21161.721625     NaN        NaN      0.296607       0.226063
# min        67.000000     NaN        NaN      0.000000       0.000000
# 25%     17741.250000     NaN        NaN      0.000000       0.000000
# 50%     36932.000000     NaN        NaN      0.000000       0.000000
# 75%     54682.000000     NaN        NaN      0.000000       0.000000
# max     72940.000000     NaN        NaN      1.000000       1.000000
#
#        ever_married work_type Residence_type avg_glucose_level   bmi  \
# count          5110      5110           5110              5110  5110
# unique            2         5              2                 5     6
# top             Yes   Private          Urban         very high   low
# freq           3353      2925           2596              1022   982
# mean            NaN       NaN            NaN               NaN   NaN
# std             NaN       NaN            NaN               NaN   NaN
# min             NaN       NaN            NaN               NaN   NaN
# 25%             NaN       NaN            NaN               NaN   NaN
# 50%             NaN       NaN            NaN               NaN   NaN
# 75%             NaN       NaN            NaN               NaN   NaN
# max             NaN       NaN            NaN               NaN   NaN
#
#        smoking_status       stroke
# count            5110  5110.000000
# unique              4          NaN
# top      never smoked          NaN
# freq             1892          NaN
# mean              NaN     0.048728
# std               NaN     0.215320
# min               NaN     0.000000
# 25%               NaN     0.000000
# 50%               NaN     0.000000
# 75%               NaN     0.000000
# max               NaN     1.000000

# %%
# Drop ID column
df = df.drop(columns = 'id')
df.head()
# Out:
#    gender        age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  very high             0              1          Yes        Private
# 1    Male  very high             0              1          Yes        Private
# 2  Female     medium             0              0          Yes        Private
# 3  Female  very high             1              0          Yes  Self-employed
# 4    Male  very high             0              0          Yes        Private
#
#   Residence_type avg_glucose_level        bmi   smoking_status  stroke
# 0          Urban         very high  very high  formerly smoked       1
# 1          Rural              high       high     never smoked       1
# 2          Urban         very high       high           smokes       1
# 3          Rural         very high        low     never smoked       1
# 4          Urban         very high     medium  formerly smoked       1

# %%
# Describe final dataset
df.describe(include='all')

# %%
# Save the transformed dataset
df.to_csv('trainingData.csv', index=False)
print('The csv was successfully saved as trainingData.csv')
# Out:
# The csv was successfully saved as trainingData.csv
